# %% [markdown]
# <a href="https://colab.research.google.com/github/yoloaryan/Learning_python/blob/main/06_PYTHON.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#CONDITIONALS
if True:
  print('Condition was true')
# Out:
# Condition was true

# %%
language ='Python'

if language == 'Python':
  print('conditions was True')
# Out:
# conditions was True

# %%
language ='JavA'

if language == 'Python':
  print('conditions was True')
else:
  print('No match')
# Out:
# No match

# %%
language ='Java'

if language == 'Python':
  print('conditions was True')
elif language == 'Java':
  print('Language is Java')
else:
  print('No match')
# Out:
# Language is Java

# %%
#and
#or
#not
user ='Admin'
logged_in= True

if user=='Admin' and logged_in:
  print('Admin Page')
else:
  print('Bad credintals')
# Out:
# Admin Page

# %%
#and
#or
#not
user ='Admin'
logged_in= True

if user=='Admin' or logged_in:
  print('Admin Page')
else:
  print('Bad credintals')
# Out:
# Admin Page

# %%
user ='Admin'
logged_in=False

if not logged_in:
  print('Admin Page')
else:
  print('Bad credintals')
# Out:
# Admin Page

# %%
a=[1,2,3]
b=[1,2,3]

print(a==b)
# Out:
# True

# %%
a=[1,2,3]
b=[1,2,3]

print(a is b)
# Out:
# False

# %%
a=[1,2,3]
b=[1,2,3]

print(id(a))

print(id(b))
# Out:
# 134289609811712
# 134289609810560

# %%
a=[1,2,3]
b=a

print(id(a))

print(id(b))
print(id(a)==id(b))
# Out:
# 134290158954048
# 134290158954048
# True
