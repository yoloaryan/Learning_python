# %% [markdown]
# <a href="https://colab.research.google.com/github/yoloaryan/Learning_python/blob/main/04_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num=3
print(type(num))
# Out:
# <class 'int'>

# %%
num=3.19

print(type(num))
# Out:
# <class 'float'>

# %%
print(3/2)
# Out:
# 1.5

# %%
print(3//2) #floor divison
# Out:
# 1

# %%
print(3*2)
# Out:
# 6

# %%
print(3**2) #exponent
# Out:
# 9

# %%
print(3%2) #modulus
# Out:
# 1

# %%
print(3 * (2+1))
# Out:
# 9

# %%
#increment of the number
num=1
num = num +1
print(num)
# Out:
# 2

# %%
num=1
num *= 12
print(num)
# Out:
# 12

# %%
print(abs(-3))
# Out:
# 3

# %%
#rounding off(1 will be the integer, then the poibnt to whic h the roundoff of teh number is supposzed to happen)

print(round(3.98,1))
# Out:
# 4.0

# %%
#comparison operator
#-> this return the boolean values

num_1= 3
num_2=2

print(num_1 == num_2)  # equal operator
print(num_1 != num_2)  # Notequal operator
print(num_1 > num_2)  #greater then
print(num_1 <  num_2)  #smaller then
print(num_1 >= num_2)  #greater then equal to
print(num_1 <= num_2)  #smaller  then equal to
# Out:
# False
# True
# True
# False
# True
# False

# %%
num_1= '100'
num_2='200'
print(num_1 + num_2)
# Out:
# 100200

# %%
#type casting
num_1= '100'
num_2='200'

num_1=int(num_1)

num_2=int(num_2)



print(num_1 + num_2)
# Out:
# 300
